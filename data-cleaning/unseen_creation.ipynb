# %% [markdown]
# # Data Cleaning / Pre-Processing

# %%
import pandas as pd

data = pd.read_csv("../csv/uncleaned/unseen_input.csv")
data.dropna()
data
# Out:
#                                          review_post
# 0                      I wanna go strawberry picking
# 1                      I wanna go boating and biking
# 2                  Worship God in a Church and pray!
# 3  market place since I wanna buy strawberry jam ...

# %%
import re
import nltk

from sklearn.feature_extraction import text
stop_words = list(text.ENGLISH_STOP_WORDS)
stop_words[0:5]
# Out:
# ['being', 'amount', 'due', 'how', 'were']

# %%
_data = data.copy()

_data['removed_special_charas_review_post'] = _data['review_post'].map(lambda x: re.sub('[^A-Za-z ]+', ' ', str(x)))
_data
# Out:
#                                          review_post  \
# 0                      I wanna go strawberry picking
# 1                      I wanna go boating and biking
# 2                  Worship God in a Church and pray!
# 3  market place since I wanna buy strawberry jam ...
#
#                   removed_special_charas_review_post
# 0                      I wanna go strawberry picking
# 1                      I wanna go boating and biking
# 2                  Worship God in a Church and pray
# 3  market place since I wanna buy strawberry jam ...

# %%
_data['to_lower_case_review_post'] = _data['removed_special_charas_review_post'].map(lambda x: x.lower())
_data
# Out:
#                                          review_post  \
# 0                      I wanna go strawberry picking
# 1                      I wanna go boating and biking
# 2                  Worship God in a Church and pray!
# 3  market place since I wanna buy strawberry jam ...
#
#                   removed_special_charas_review_post  \
# 0                      I wanna go strawberry picking
# 1                      I wanna go boating and biking
# 2                  Worship God in a Church and pray
# 3  market place since I wanna buy strawberry jam ...
#
#                            to_lower_case_review_post
# 0                      i wanna go strawberry picking
# 1                      i wanna go boating and biking
# 2                  worship god in a church and pray
# 3  market place since i wanna buy strawberry jam ...

# %%
_data['removed_stop_words_review_post'] = _data['to_lower_case_review_post'].map(lambda x: " ".join(x for x in x.split() if x not in stop_words))
_data
# Out:
#                                          review_post  \
# 0                      I wanna go strawberry picking
# 1                      I wanna go boating and biking
# 2                  Worship God in a Church and pray!
# 3  market place since I wanna buy strawberry jam ...
#
#                   removed_special_charas_review_post  \
# 0                      I wanna go strawberry picking
# 1                      I wanna go boating and biking
# 2                  Worship God in a Church and pray
# 3  market place since I wanna buy strawberry jam ...
#
#                            to_lower_case_review_post  \
# 0                      i wanna go strawberry picking
# 1                      i wanna go boating and biking
# 2                  worship god in a church and pray
# 3  market place since i wanna buy strawberry jam ...
#
#                       removed_stop_words_review_post
# 0                           wanna strawberry picking
# 1                               wanna boating biking
# 2                            worship god church pray
# 3  market place wanna buy strawberry jam ube jam ...

# %%
from nltk.stem.wordnet import WordNetLemmatizer

lem = WordNetLemmatizer()

_data['lemmatized_words_review_post'] = _data['removed_stop_words_review_post'].map(lambda x: " ".join(lem.lemmatize(str(x)) for x in x.split()))
_data
# Out:
#                                          review_post  \
# 0                      I wanna go strawberry picking
# 1                      I wanna go boating and biking
# 2                  Worship God in a Church and pray!
# 3  market place since I wanna buy strawberry jam ...
#
#                   removed_special_charas_review_post  \
# 0                      I wanna go strawberry picking
# 1                      I wanna go boating and biking
# 2                  Worship God in a Church and pray
# 3  market place since I wanna buy strawberry jam ...
#
#                            to_lower_case_review_post  \
# 0                      i wanna go strawberry picking
# 1                      i wanna go boating and biking
# 2                  worship god in a church and pray
# 3  market place since i wanna buy strawberry jam ...
#
#                       removed_stop_words_review_post  \
# 0                           wanna strawberry picking
# 1                               wanna boating biking
# 2                            worship god church pray
# 3  market place wanna buy strawberry jam ube jam ...
#
#                         lemmatized_words_review_post
# 0                           wanna strawberry picking
# 1                               wanna boating biking
# 2                            worship god church pray
# 3  market place wanna buy strawberry jam ube jam ...

# %%
_data.to_csv('../csv/cleaned/cleaned_unseen.csv', index = False)

# %%
import spacy

selected_tags = ["NOUN", "ADJ", "ADV", "PROPN", "VERB", "X"]
tag_compil = {"NOUN" : [], "ADJ" : [], "ADV" : [], "PROPN" : [], "VERB" : [], "X" : []}

for idx, value in enumerate(list(_data['lemmatized_words_review_post'])):
    print("Loop: ", idx)
    sp = spacy.load('en_core_web_sm')
    sen = sp(value)

    pos_tagged = []
    selected_tags = {"NOUN" : 0, "ADJ" : 0, "ADV" : 0, "PROPN" : 0, "VERB" : 0, "X" : 0}

    for word in sen:
        if word.pos_ in selected_tags.keys():
            selected_tags[str(word.pos_)] += 1
            #pos_tagged.append((word.text, word.pos_))
    
    for idx, value in tag_compil.items():
        tag_compil[str(idx)].append(selected_tags[str(idx)])

tag_compil
# Out:
# Loop:  0
# Loop:  1
# Loop:  2
# Loop:  3
# {'NOUN': [0, 1, 2, 2],
#  'ADJ': [0, 0, 0, 1],
#  'ADV': [0, 0, 0, 0],
#  'PROPN': [2, 1, 1, 6],
#  'VERB': [1, 1, 1, 1],
#  'X': [0, 0, 0, 0]}

# %%
new = pd.DataFrame.from_dict(tag_compil)

new.to_csv("../csv/uncleaned/unseen_pos_tags.csv", index = False)
new
# Out:
#    NOUN  ADJ  ADV  PROPN  VERB  X
# 0     0    0    0      2     1  0
# 1     1    0    0      1     1  0
# 2     2    0    0      1     1  0
# 3     2    1    0      6     1  0

# %%
for tag in selected_tags:
    _data[str(tag)] = tag_compil[str(tag)]

_data
# Out:
#                                          review_post  \
# 0                      I wanna go strawberry picking
# 1                      I wanna go boating and biking
# 2                  Worship God in a Church and pray!
# 3  market place since I wanna buy strawberry jam ...
#
#                   removed_special_charas_review_post  \
# 0                      I wanna go strawberry picking
# 1                      I wanna go boating and biking
# 2                  Worship God in a Church and pray
# 3  market place since I wanna buy strawberry jam ...
#
#                            to_lower_case_review_post  \
# 0                      i wanna go strawberry picking
# 1                      i wanna go boating and biking
# 2                  worship god in a church and pray
# 3  market place since i wanna buy strawberry jam ...
#
#                       removed_stop_words_review_post  \
# 0                           wanna strawberry picking
# 1                               wanna boating biking
# 2                            worship god church pray
# 3  market place wanna buy strawberry jam ube jam ...
#
#                         lemmatized_words_review_post  NOUN  ADJ  ADV  PROPN  \
# 0                           wanna strawberry picking     0    0    0      2
# 1                               wanna boating biking     1    0    0      1
# 2                            worship god church pray     2    0    0      1
# 3  market place wanna buy strawberry jam ube jam ...     2    1    0      6
#
#    VERB  X
# 0     1  0
# 1     1  0
# 2     1  0
# 3     1  0

# %%
from textblob import TextBlob

def analyze_score(score):
    if score < 0:
        return 'Negative'
    elif score == 0:
        return 'Neutral'
    else:
        return 'Positive'

_data['subjectivity'] = _data['lemmatized_words_review_post'].map(lambda x: TextBlob(x).sentiment.subjectivity)
_data['polarity'] = _data['lemmatized_words_review_post'].map(lambda x: TextBlob(x).sentiment.polarity)
_data['sent_analysis'] = _data['polarity'].map(lambda x: analyze_score(x))

_data.drop(['subjectivity', 'polarity'], axis=1, inplace = True)
_data
# Out:
#                                          review_post  \
# 0                      I wanna go strawberry picking
# 1                      I wanna go boating and biking
# 2                  Worship God in a Church and pray!
# 3  market place since I wanna buy strawberry jam ...
#
#                   removed_special_charas_review_post  \
# 0                      I wanna go strawberry picking
# 1                      I wanna go boating and biking
# 2                  Worship God in a Church and pray
# 3  market place since I wanna buy strawberry jam ...
#
#                            to_lower_case_review_post  \
# 0                      i wanna go strawberry picking
# 1                      i wanna go boating and biking
# 2                  worship god in a church and pray
# 3  market place since i wanna buy strawberry jam ...
#
#                       removed_stop_words_review_post  \
# 0                           wanna strawberry picking
# 1                               wanna boating biking
# 2                            worship god church pray
# 3  market place wanna buy strawberry jam ube jam ...
#
#                         lemmatized_words_review_post  NOUN  ADJ  ADV  PROPN  \
# 0                           wanna strawberry picking     0    0    0      2
# 1                               wanna boating biking     1    0    0      1
# 2                            worship god church pray     2    0    0      1
# 3  market place wanna buy strawberry jam ube jam ...     2    1    0      6
#
#    VERB  X sent_analysis
# 0     1  0       Neutral
# 1     1  0       Neutral
# 2     1  0       Neutral
# 3     1  0       Neutral

# %%
_data.to_csv("../csv/cleaned/cleaned_unseen_input.csv", index = False)
_data
# Out:
#                                          review_post  \
# 0                      I wanna go strawberry picking
# 1                      I wanna go boating and biking
# 2                  Worship God in a Church and pray!
# 3  market place since I wanna buy strawberry jam ...
#
#                   removed_special_charas_review_post  \
# 0                      I wanna go strawberry picking
# 1                      I wanna go boating and biking
# 2                  Worship God in a Church and pray
# 3  market place since I wanna buy strawberry jam ...
#
#                            to_lower_case_review_post  \
# 0                      i wanna go strawberry picking
# 1                      i wanna go boating and biking
# 2                  worship god in a church and pray
# 3  market place since i wanna buy strawberry jam ...
#
#                       removed_stop_words_review_post  \
# 0                           wanna strawberry picking
# 1                               wanna boating biking
# 2                            worship god church pray
# 3  market place wanna buy strawberry jam ube jam ...
#
#                         lemmatized_words_review_post  NOUN  ADJ  ADV  PROPN  \
# 0                           wanna strawberry picking     0    0    0      2
# 1                               wanna boating biking     1    0    0      1
# 2                            worship god church pray     2    0    0      1
# 3  market place wanna buy strawberry jam ube jam ...     2    1    0      6
#
#    VERB  X sent_analysis
# 0     1  0       Neutral
# 1     1  0       Neutral
# 2     1  0       Neutral
# 3     1  0       Neutral

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import scipy

x = _data[['NOUN', 'ADJ', 'ADV', 'PROPN', 'VERB', 'X']]

tfv = TfidfVectorizer(stop_words = 'english')
tfv_text = tfv.fit_transform(_data['lemmatized_words_review_post'].values.astype('U'))

tfv_text_df = pd.DataFrame(tfv_text.todense())
combined = pd.concat([x, tfv_text_df], axis=1, join='inner')

sparsed_data = scipy.sparse.csr_matrix(combined.values)

# %%
combined
# Out:
#    NOUN  ADJ  ADV  PROPN  VERB  X         0         1         2         3  \
# 0     0    0    0      2     1  0  0.000000  0.000000  0.000000  0.000000
# 1     1    0    0      1     1  0  0.000000  0.644503  0.644503  0.000000
# 2     2    0    0      1     1  0  0.000000  0.000000  0.000000  0.000000
# 3     2    1    0      6     1  0  0.301115  0.000000  0.000000  0.301115
#
#    ...         6         7         8         9   10        11        12  \
# 0  ...  0.000000  0.000000  0.702035  0.000000  0.0  0.000000  0.553492
# 1  ...  0.000000  0.000000  0.000000  0.000000  0.0  0.000000  0.000000
# 2  ...  0.000000  0.000000  0.000000  0.000000  0.5  0.000000  0.000000
# 3  ...  0.602229  0.301115  0.000000  0.301115  0.0  0.301115  0.237402
#
#          13        14   15
# 0  0.000000  0.448100  0.0
# 1  0.000000  0.411378  0.0
# 2  0.000000  0.000000  0.5
# 3  0.301115  0.192198  0.0
#
# [4 rows x 22 columns]

# %%
import pickle

# load it again
with open('../models/svm_classifier.pkl', 'rb') as fid:
    svm = pickle.load(fid)
# Out:
# d:\anaconda3\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator SVC from version 1.1.3 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
dest_pred = svm.predict(sparsed_data)
actual_predict = pd.DataFrame()
actual_predict["actual"] = dest_test
actual_predict["predict"] = dest_pred
actual_predict
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [24], line 1
# ----> 1 dest_pred = svm.predict(sparsed_data)
#       2 actual_predict = pd.DataFrame()
#       3 actual_predict["actual"] = dest_test
#
# File d:\anaconda3\lib\site-packages\sklearn\svm\_base.py:791, in BaseSVC.predict(self, X)
#     789     y = np.argmax(self.decision_function(X), axis=1)
#     790 else:
# --> 791     y = super().predict(X)
#     792 return self.classes_.take(np.asarray(y, dtype=np.intp))
#
# File d:\anaconda3\lib\site-packages\sklearn\svm\_base.py:414, in BaseLibSVM.predict(self, X)
#     398 def predict(self, X):
#     399     """Perform regression on samples in X.
#     400
#     401     For an one-class model, +1 (inlier) or -1 (outlier) is returned.
#    (...)
#     412         The predicted values.
#     413     """
# --> 414     X = self._validate_for_predict(X)
#     415     predict = self._sparse_predict if self._sparse else self._dense_predict
#     416     return predict(X)
#
# File d:\anaconda3\lib\site-packages\sklearn\svm\_base.py:592, in BaseLibSVM._validate_for_predict(self, X)
#     589 check_is_fitted(self)
#     591 if not callable(self.kernel):
# --> 592     X = self._validate_data(
#     593         X,
#     594         accept_sparse="csr",
#     595         dtype=np.float64,
#     596         order="C",
#     597         accept_large_sparse=False,
#     598         reset=False,
#     599     )
#     601 if self._sparse and not sp.isspmatrix(X):
#     602     X = sp.csr_matrix(X)
#
# File d:\anaconda3\lib\site-packages\sklearn\base.py:585, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     582     out = X, y
#     584 if not no_val_X and check_params.get("ensure_2d", True):
# --> 585     self._check_n_features(X, reset=reset)
#     587 return out
#
# File d:\anaconda3\lib\site-packages\sklearn\base.py:400, in BaseEstimator._check_n_features(self, X, reset)
#     397     return
#     399 if n_features != self.n_features_in_:
# --> 400     raise ValueError(
#     401         f"X has {n_features} features, but {self.__class__.__name__} "
#     402         f"is expecting {self.n_features_in_} features as input."
#     403     )
#
# ValueError: X has 22 features, but SVC is expecting 8326 features as input.

# %%
from sklearn.metrics import classification_report
print(classification_report(dest_test, dest_pred))

# calculate accuracy of class predictions
from sklearn import metrics
print(f'Accuracy -> ', metrics.accuracy_score(dest_test, dest_pred))
